# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Import dataset

# %%
def messy_vol_acidity(value:str):
    choice = np.random.randint(0, 3)
    if choice == 0: # clean string volatile acidity
        return value
    elif choice == 1: # replace decimal point with comma
        return value.replace('.', ',')
    else: # add volatile acidity units
        return f'{value} g/L'

def make_dirty(df: pd.DataFrame):
    np.random.seed(1)
    dirty = df.copy()

    # Casts volatile acidity and quality columns to string
    dirty['volatile acidity'] = dirty['volatile acidity'].astype(str)
    dirty['quality'] = dirty['quality'].astype(str)


    # inconsistent string format
    dirty['volatile acidity'] = dirty['volatile acidity'].apply(messy_vol_acidity)

    # add random duplicates rows (approx. 2% of the data)
    dup_indices = np.random.choice(dirty.index, size=32, replace=False) # indices of rows to duplicate
    dup_rows = dirty.iloc[dup_indices]

    dirty = pd.concat(objs=[dirty, dup_rows]).reset_index(drop=True)

    # add NaNs across 2% of values to 4 columns (pH, alcohol, total sulfure dioxide, and residual sugar)
    for col in ['pH', 'alcohol', 'total sulfur dioxide', 'residual sugar']:
        s = int(np.ceil(len(dirty.index)*0.02))
        nan_indices = np.random.choice(dirty.index, size=s, replace=False) # indices of rows to NaN
        dirty.loc[nan_indices, col] = None


    # adds inconsistent column name format (extra spaces)
    dirty.columns = dirty.columns.str.replace(' ', '   ')

    # add column values to quality column that can be mapped to existing values (2% of rows)
    qual_map = {
        '1': 'one',
        '2': 'two',
        '3': 'three',
        '4': 'four',
        '5': 'five',
        '6': 'six',
        '7': 'seven',
        '8': 'eight',
        '9': 'nine',
        '10': 'ten',
    }

    s = int(np.ceil(len(dirty.index)*0.02))
    qual_indices = np.random.choice(dirty.index, size=s, replace=False) # indices of rows to convert to text based num

    dirty.loc[qual_indices, 'quality'] = dirty.loc[qual_indices, 'quality'].map(qual_map)

    return dirty, dup_indices

# %%
wine_df, _ = make_dirty(pd.read_csv('./winequality-red.csv'))

wine_df.head(10)
# Out:
#    fixed   acidity volatile   acidity  citric   acid  residual   sugar  \
# 0              7.4                0,7           0.00               1.9
# 1              7.8               0.88           0.00               2.6
# 2              7.8               0.76           0.04               2.3
# 3             11.2               0,28           0.56               1.9
# 4              7.4                0,7           0.00               1.9
# 5              7.4               0.66           0.00               1.8
# 6              7.9                0.6           0.06               1.6
# 7              7.3               0,65           0.00               1.2
# 8              7.8               0.58           0.02               2.0
# 9              7.5                0,5           0.36               NaN
#
#    chlorides  free   sulfur   dioxide  total   sulfur   dioxide  density  \
# 0      0.076                     11.0                      34.0   0.9978
# 1      0.098                     25.0                      67.0   0.9968
# 2      0.092                     15.0                      54.0   0.9970
# 3      0.075                     17.0                      60.0   0.9980
# 4      0.076                     11.0                      34.0   0.9978
# 5      0.075                     13.0                      40.0   0.9978
# 6      0.069                     15.0                       NaN   0.9964
# 7      0.065                     15.0                      21.0   0.9946
# 8      0.073                      9.0                      18.0   0.9968
# 9      0.071                     17.0                     102.0   0.9978
#
#      pH  sulphates  alcohol quality
# 0  3.51       0.56      9.4       5
# 1  3.20       0.68      9.8       5
# 2  3.26       0.65      9.8       5
# 3  3.16       0.58      9.8       6
# 4  3.51       0.56      9.4       5
# 5   NaN       0.56      9.4       5
# 6  3.30       0.46      9.4       5
# 7  3.39       0.47     10.0       7
# 8  3.36       0.57      9.5       7
# 9  3.35       0.80     10.5       5

# %%
print("Shape:", wine_df.shape, '\n')

print(f'Columns: \n{",".join(wine_df.columns.tolist())}\n')

wine_df.info()
# Out:
# Shape: (1631, 12)
#
# Columns:
# fixed   acidity,volatile   acidity,citric   acid,residual   sugar,chlorides,free   sulfur   dioxide,total   sulfur   dioxide,density,pH,sulphates,alcohol,quality
#
# <class 'pandas.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   fixed   acidity           1631 non-null   float64
#  1   volatile   acidity        1631 non-null   str
#  2   citric   acid             1631 non-null   float64
#  3   residual   sugar          1598 non-null   float64
#  4   chlorides                 1631 non-null   float64
#  5   free   sulfur   dioxide   1631 non-null   float64
#  6   total   sulfur   dioxide  1598 non-null   float64
#  7   density                   1631 non-null   float64
#  8   pH                        1598 non-null   float64
#  9   sulphates                 1631 non-null   float64
#  10  alcohol                   1598 non-null   float64
#  11  quality                   1631 non-null   str
# dtypes: float64(10), str(2)
# memory usage: 153.0 KB

# %%
wine_df.isna().sum()
# Out:
# fixed   acidity              0
# volatile   acidity           0
# citric   acid                0
# residual   sugar            33
# chlorides                    0
# free   sulfur   dioxide      0
# total   sulfur   dioxide    33
# density                      0
# pH                          33
# sulphates                    0
# alcohol                     33
# quality                      0
# dtype: int64

# %%
wine_df.duplicated().sum()
# Out:
# np.int64(95)

# %%
wine_df['volatile   acidity'].unique().tolist()
# Out:
# ['0,7',
#  '0.88',
#  '0.76',
#  '0,28',
#  '0.66',
#  '0.6',
#  '0,65',
#  '0.58',
#  '0,5',
#  '0.5 g/L',
#  '0,615',
#  '0.61 g/L',
#  '0.62',
#  '0.62 g/L',
#  '0.56 g/L',
#  '0.59',
#  '0.32',
#  '0.22 g/L',
#  '0.39',
#  '0,43',
#  '0.49 g/L',
#  '0.4 g/L',
#  '0,41',
#  '0.71 g/L',
#  '0.645',
#  '0.675 g/L',
#  '0,685',
#  '0,655',
#  '0,605',
#  '0,32',
#  '0.645 g/L',
#  '0,6',
#  '0,38',
#  '1.13',
#  '0.45',
#  '0,45',
#  '0.61',
#  '0.49',
#  '0,66',
#  '0.67 g/L',
#  '0,52',
#  '0.935',
#  '0.29 g/L',
#  '0,31',
#  '0.5',
#  '0.38',
#  '0,51',
#  '0.42 g/L',
#  '0.63',
#  '0,39',
#  '0,4',
#  '0.69 g/L',
#  '0.52',
#  '0.735',
#  '0,725',
#  '0.725 g/L',
#  '0.52 g/L',
#  '0,705',
#  '0.705 g/L',
#  '0,63',
#  '0,69',
#  '0.675',
#  '0.41 g/L',
#  '0.785',
#  '0.75',
#  '0.625 g/L',
#  '0.45 g/L',
#  '0.3 g/L',
#  '0.55 g/L',
#  '0,62',
#  '0,49',
#  '1,02',
#  '0.6 g/L',
#  '0.775',
#  '0.9 g/L',
#  '0.545 g/L',
#  '0,545',
#  '0.575',
#  '0,33',
#  '0,56',
#  '0.31 g/L',
#  '0.56',
#  '0.54 g/L',
#  '0,55',
#  '1.07',
#  '0.695',
#  '0.71',
#  '1,33',
#  '1.33 g/L',
#  '0.745',
#  '1.04',
#  '0.715 g/L',
#  '0.415 g/L',
#  '0,745',
#  '0.34 g/L',
#  '0.39 g/L',
#  '0.67',
#  '0.68 g/L',
#  '0.33',
#  '0.43 g/L',
#  '0,68',
#  '0.95',
#  '0.53',
#  '0,64',
#  '0.55',
#  '0,885',
#  '0,42',
#  '0.805',
#  '0,61',
#  '0,73',
#  '0.31',
#  '0.705',
#  '0,37',
#  '0,835',
#  '1.09',
#  '0.32 g/L',
#  '0.37 g/L',
#  '0.42',
#  '0,3',
#  '0,57',
#  '0.44 g/L',
#  '0.3',
#  '0.44',
#  '0.625',
#  '0,34',
#  '0,635',
#  '0,59',
#  '0.82',
#  '0.43',
#  '0,48',
#  '0.38 g/L',
#  '0.37',
#  '1.0 g/L',
#  '0.63 g/L',
#  '0.635',
#  '0.21',
#  '0.53 g/L',
#  '0.35 g/L',
#  '0.775 g/L',
#  '0.57',
#  '0.695 g/L',
#  '0.975',
#  '0,26',
#  '0.87',
#  '0,18',
#  '0,715',
#  '0.65 g/L',
#  '0.545',
#  '0.54',
#  '0.18 g/L',
#  '0.4',
#  '0.27 g/L',
#  '0,2',
#  '0.36',
#  '0.34',
#  '0.83',
#  '0,67',
#  '0.65',
#  '0,53',
#  '0,46',
#  '0.47 g/L',
#  '0.36 g/L',
#  '0.35',
#  '0.77',
#  '0.66 g/L',
#  '0.59 g/L',
#  '0,27',
#  '0.46 g/L',
#  '0,36',
#  '0,58',
#  '0,695',
#  '0.28 g/L',
#  '0.57 g/L',
#  '0.685',
#  '0.815 g/L',
#  '0.795 g/L',
#  '0,665',
#  '0.21 g/L',
#  '0.75 g/L',
#  '0.615',
#  '0.615 g/L',
#  '0,575',
#  '0.27',
#  '0.765 g/L',
#  '0.24 g/L',
#  '0.41',
#  '0,415',
#  '0.26 g/L',
#  '0,54',
#  '0.46',
#  '0.85',
#  '0,765',
#  '0.735 g/L',
#  '0.48',
#  '0.69',
#  '0,77',
#  '0.84',
#  '0.96 g/L',
#  '0.78',
#  '0.84 g/L',
#  '0,24',
#  '0.685 g/L',
#  '0,735',
#  '0.48 g/L',
#  '0.33 g/L',
#  '0.23',
#  '0.58 g/L',
#  '0.26',
#  '0,315',
#  '0,82',
#  '0,35',
#  '0.68',
#  '0,44',
#  '0.24',
#  '0,29',
#  '0.51',
#  '0.655',
#  '0,21',
#  '0,365',
#  '0.25',
#  '0.64 g/L',
#  '0.365 g/L',
#  '0.22',
#  '0,825',
#  '0,645',
#  '0.29',
#  '0.7 g/L',
#  '0.47',
#  '0.28',
#  '0.51 g/L',
#  '0.73 g/L',
#  '0,72',
#  '0.595 g/L',
#  '0,585',
#  '0.915 g/L',
#  '0.835 g/L',
#  '0.755 g/L',
#  '0.885 g/L',
#  '0.915',
#  '0.845 g/L',
#  '0.88 g/L',
#  '0,47',
#  '0.73',
#  '1,24',
#  '0,8',
#  '0,78',
#  '0,98',
#  '1,185',
#  '0,92',
#  '1.02',
#  '0.64',
#  '1.035',
#  '1.025',
#  '0.565',
#  '0.74',
#  '1.115',
#  '0.865 g/L',
#  '0,875',
#  '0.835',
#  '0.965 g/L',
#  '0,76',
#  '0,91',
#  '0.98',
#  '0.655 g/L',
#  '0.72 g/L',
#  '0.82 g/L',
#  '0.89 g/L',
#  '0.665',
#  '0,25',
#  '1,01',
#  '0.635 g/L',
#  '0.715',
#  '0,75',
#  '0.8 g/L',
#  '0,9',
#  '0.305 g/L',
#  '0.395',
#  '0.305',
#  '0.12 g/L',
#  '0,12',
#  '0.86',
#  '0,295',
#  '1.005',
#  '0,71',
#  '0.18',
#  '0,83',
#  '0,795',
#  '0.745 g/L',
#  '0.78 g/L',
#  '0.605',
#  '0,23',
#  '0.74 g/L',
#  '0.77 g/L',
#  '0.19 g/L',
#  '0.76 g/L',
#  '0.19',
#  '0.2',
#  '0,785',
#  '0,955',
#  '0.885',
#  '0.72',
#  '0,74',
#  '0.765',
#  '0.16',
#  '0.395 g/L',
#  '0.755',
#  '1.58 g/L',
#  '0,86',
#  '0.79 g/L',
#  '1.18',
#  '0,87',
#  '0.475 g/L',
#  '0,755',
#  '0,81',
#  '0.96',
#  '0.2 g/L',
#  '0.98 g/L',
#  '0.7',
#  '0.875',
#  '0.91',
#  '0.895',
#  '0,79',
#  '0.855 g/L',
#  '0.855',
#  '0.16 g/L']

# %%
wine_df['quality'].unique().tolist()
# Out:
# ['5', '6', '7', '4', 'six', 'five', '8', '3', 'eight', 'four', 'seven']

# %% [markdown]
# ## Clean Data (parse and organize)

# %%
# fix column name format
wine_df.columns = wine_df.columns.str.replace(r'\s+', ' ', regex=True)

# map string qualities to numbers and cast column to numeric
qual_map = {
    'one': '1',
    'two': '2',
    'three': '3',
    'four': '4',
    'five': '5',
    'six': '6',
    'seven': '7',
    'eight': '8',
    'nine': '9',
    'ten': '10',
}

wine_df['quality'] = wine_df['quality'].replace(qual_map)
wine_df['quality'] = wine_df['quality'].astype(int)

# normalize format of volatile acidity and cast column to numeric
def clean_vol_acidity(value:str):
    return value.replace(',', '.').replace('g/L', '').strip()

wine_df['volatile acidity'] = wine_df['volatile acidity'].apply(clean_vol_acidity)
wine_df['volatile acidity'] = wine_df['volatile acidity'].astype(float)

# Drop duplicate rows
wine_df.drop_duplicates(inplace=True)

# impute NaNs with median of known values
for col in ['residual sugar', 'total sulfur dioxide', 'pH', 'alcohol']:
    wine_df[col] = wine_df[col].fillna(wine_df[col].median())

wine_df.head(10)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4              0.70         0.00             1.9      0.076
# 1             7.8              0.88         0.00             2.6      0.098
# 2             7.8              0.76         0.04             2.3      0.092
# 3            11.2              0.28         0.56             1.9      0.075
# 5             7.4              0.66         0.00             1.8      0.075
# 6             7.9              0.60         0.06             1.6      0.069
# 7             7.3              0.65         0.00             1.2      0.065
# 8             7.8              0.58         0.02             2.0      0.073
# 9             7.5              0.50         0.36             2.2      0.071
# 10            6.7              0.58         0.08             1.8      0.097
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 5                  13.0                  40.0   0.9978  3.31       0.56
# 6                  15.0                  38.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
#
#     alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 5       9.4        5
# 6       9.4        5
# 7      10.0        7
# 8       9.5        7
# 9      10.5        5
# 10      9.2        5

# %% [markdown]
# # Data Exploration & Summary Statistics

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1398.000000       1398.000000  1398.000000     1398.000000
# mean        8.308941          0.528516     0.271488        2.513233
# std         1.741333          0.181708     0.194873        1.327447
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1398.000000          1398.000000           1398.000000  1398.000000
# mean      0.087806            15.880544             46.669170     0.996717
# std       0.048752            10.386967             32.972497     0.001870
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996700
# 75%       0.090000            21.000000             62.000000     0.997827
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1398.000000  1398.000000  1398.000000  1398.000000
# mean      3.310837     0.657933    10.421757     5.625894
# std       0.153329     0.169329     1.068144     0.820000
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
wine_df.head() # wide data format, needs to be in long format to plot with seaborn

wine_long = wine_df.melt(var_name='feature') # melt data to long format

# create facet grid plot that facets on each feature, showing a histogram (distribution) of the feature's values
g = sns.FacetGrid(wine_long, col='feature', col_wrap=4, sharex=False, sharey=False)
g.map(sns.histplot, "value", bins=10)

g.set_titles(col_template='{col_name}') # each subplot's title is the feature name

plt.suptitle('Feature Distributions', y=1.01)

plt.show()

# Most distributions are not normal --> Use non-parametric tests

# %% [markdown]
# ## Spearman correlation matrix

# %%
alpha = 0.05 # level of significance in hypothesis testing

# Find significant predictors
print(f"{'Feature':<25} {'Rho':>7} {'p-value':>10} {'significance':>15}")
print('-' * 60)

# loops thru all columns except quality
for col in wine_df.columns[:-1]: 
    # Calculate a Spearman correlation coefficient with associated p-value
    rho, p = stats.spearmanr(wine_df[col], wine_df['quality']) 
    significant = 'yes' if p < alpha else 'no'
    print(f"{col:<25} {rho:>8.3f} {p:>10.4f} {significant:>12}") # print each feature with formatted rho coeff. and p-value
    

# spearman rho correlation coeff. matrix (measures monotonic relationships)
corr_matrix = wine_df.corr('spearman')

# True in upper triangle (heatmap hides these), k=1 shifts off main diagonal so perf. relationships stay visible
mask = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)

g = sns.heatmap(corr_matrix,
                mask=mask, # data in cells where mask=True are hidden (hides upper half of heatmap)
                annot=True, # display spearman rho correlation coeff. values
                annot_kws={'fontsize': 'small'}, # reduce fontsize
                fmt='.2f', # round to 2 decimal places
                center=0, # center color mapping at 0 (no monotonic relationship)
                linewidths=0.5, 
                cmap='coolwarm',
                vmin=-1, 
                vmax=1
)

g.set_title('Spearman Correlation Matrix')

plt.show()
# Out:
# Feature                       Rho    p-value    significance
# ------------------------------------------------------------
# fixed acidity                0.109     0.0000          yes
# volatile acidity            -0.385     0.0000          yes
# citric acid                  0.215     0.0000          yes
# residual sugar               0.026     0.3260           no
# chlorides                   -0.206     0.0000          yes
# free sulfur dioxide         -0.057     0.0332          yes
# total sulfur dioxide        -0.198     0.0000          yes
# density                     -0.183     0.0000          yes
# pH                          -0.042     0.1153           no
# sulphates                    0.381     0.0000          yes
# alcohol                      0.475     0.0000          yes

# %% [markdown]
# Nine out of eleven features show statistically significant monotonic relationships with quality since $p < 0.05$. This means we reject $H_0$ ($p=0$) for those features. Residual sugar and pH fail to reject $H_0$ and thus their correlations could be noise.

# %% [markdown]
# # Hypothesis Testing

# %%
quality_groups = [group["volatile acidity"].values for name, group in wine_df.groupby("quality")]

stat, p_value = stats.kruskal(*quality_groups)

print(f"Kruskal-Wallis H-statistic: {stat}")
print(f"p-value: {p_value}")

alpha = 0.05
if p_value < alpha:
    print("Result: Statistically Significant. We reject the null hypothesis.")
    print("Conclusion: Volatile acidity levels vary significantly between different wine qualities.")
else:
    print("Result: Not Statistically Significant. Fail to reject the null hypothesis.")

plt.figure(figsize=(12, 8))
sns.boxplot(x='quality', y='volatile acidity', hue='quality', data=wine_df, legend=False)

plt.title('Volatile Acidity vs. Wine Quality')
plt.xlabel('Quality Rating')
plt.ylabel('Volatile Acidity (g/L)')
plt.show()
# Out:
# Kruskal-Wallis H-statistic: 217.02018582409542
# p-value: 6.459872974487279e-45
# Result: Statistically Significant. We reject the null hypothesis.
# Conclusion: Volatile acidity levels vary significantly between different wine qualities.

# %% [markdown]
# # Linear Regression

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(wine_df['volatile acidity'], wine_df['quality'])

print(f"Relationship: for every 1 unit increase in volatile acidity, quality drops by {abs(slope):.2f} points")
print(f"R-squared (fit strength): {r_value**2:.2f}")
print(f"Conclusion: shows a negative relationship where an increase in volatile acidity predicts a decrease in wine quality")

plt.figure(figsize=(10, 6))
sns.regplot(x='volatile acidity', y='quality', data=wine_df, scatter_kws={'alpha':0.3})

plt.title('Relationship: how volatile acidity affects quality')
plt.xlabel('Volatile Acidity (g/L)')
plt.ylabel('Quality Rating')
plt.show()
# Out:
# Relationship: for every 1 unit increase in volatile acidity, quality drops by 1.78 points
# R-squared (fit strength): 0.16
# Conclusion: shows a negative relationship where an increase in volatile acidity predicts a decrease in wine quality
